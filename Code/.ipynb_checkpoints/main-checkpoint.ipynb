# %%
from Clause import clause
from whereCond import train,test
from Graph import from_query
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-68434b2987ad> in <module>
#       1 from Clause import clause
# ----> 2 from whereCond import train,test
#       3 from Graph import from_query
#
# ~/Desktop/natural-to-sql/Code/whereCond.py in <module>
#      11 from nltk.corpus import stopwords
#      12 # from sklearn.ensemble import RandomForestClassifier
# ---> 13 from xgboost import XGBClassifier,Booster,DMatrix
#      14 from sklearn.preprocessing import LabelEncoder
#      15 from sklearn.metrics import classification_report
#
# ModuleNotFoundError: No module named 'xgboost'
